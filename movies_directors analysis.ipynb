# %% [markdown]
# #              Factors Influencing Movie Success: A Data Analysis

# %% [markdown]
# ## Introduction
# #### * The world of cinema is vast and complex, with multiple factors contributing to the success or failure of a movie.
# #### * Directors play a pivotal role in shaping the final product, and understanding how a director's influence interacts with key movie metrics such as budget, popularity, and revenue can provide valuable insights.
# #### * This project focuses on analyzing two Kaggle datasets—one containing movie data and the other containing director information.
# #### * We will merge these datasets to explore the relationships between various features such as movie budget, revenue, profit, director's gender, and the movie's popularity.

# %% [markdown]
# ## Objective
# #### The primary objectives of this project is Analyze relationships between key factors such as budget, revenue, profit, vote_average, director's gender, and popularity.

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
movies=pd.read_csv('movies.csv')

# %%
directors=pd.read_csv('directors.csv')

# %%
movies
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# ...          ...    ...        ...         ...         ...
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
# 1462        4748  48375          0           7           0
# 1463        4749  48376          0           3           0
# 1464        4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
directors
# Out:
#       Unnamed: 0      director_name    id gender
# 0              0      James Cameron  4762   Male
# 1              1     Gore Verbinski  4763   Male
# 2              2         Sam Mendes  4764   Male
# 3              3  Christopher Nolan  4765   Male
# 4              4     Andrew Stanton  4766   Male
# ...          ...                ...   ...    ...
# 2344        2344      Shane Carruth  7106   Male
# 2345        2345   Neill Dela Llana  7107    NaN
# 2346        2346        Scott Smith  7108    NaN
# 2347        2347        Daniel Hsia  7109   Male
# 2348        2348   Brian Herzlinger  7110   Male
#
# [2349 rows x 4 columns]

# %% [markdown]
# # Merging of Two datasets

# %%
df=pd.merge(movies,directors,left_on='director_id',right_on='id',how='left')

# %%
df
# Out:
#       Unnamed: 0_x   id_x     budget  popularity     revenue  \
# 0                0  43597  237000000         150  2787965087
# 1                1  43598  300000000         139   961000000
# 2                2  43599  245000000         107   880674609
# 3                3  43600  250000000         112  1084939099
# 4                5  43602  258000000         115   890871626
# ...            ...    ...        ...         ...         ...
# 1460          4736  48363          0           3      321952
# 1461          4743  48370      27000          19     3151130
# 1462          4748  48375          0           7           0
# 1463          4749  48376          0           3           0
# 1464          4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
df.drop(['Unnamed: 0_x','Unnamed: 0_y'],axis=1,inplace=True)

# %%
df.rename(columns={'id_x':'movie_id'},inplace=True)

# %%
df
# Out:
#       movie_id     budget  popularity     revenue  \
# 0        43597  237000000         150  2787965087
# 1        43598  300000000         139   961000000
# 2        43599  245000000         107   880674609
# 3        43600  250000000         112  1084939099
# 4        43602  258000000         115   890871626
# ...        ...        ...         ...         ...
# 1460     48363          0           3      321952
# 1461     48370      27000          19     3151130
# 1462     48375          0           7           0
# 1463     48376          0           3           0
# 1464     48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# ...

# %%
df.drop(['id_y'],axis=1,inplace=True)

# %%
df
# Out:
#       movie_id     budget  popularity     revenue  \
# 0        43597  237000000         150  2787965087
# 1        43598  300000000         139   961000000
# 2        43599  245000000         107   880674609
# 3        43600  250000000         112  1084939099
# 4        43602  258000000         115   890871626
# ...        ...        ...         ...         ...
# 1460     48363          0           3      321952
# 1461     48370      27000          19     3151130
# 1462     48375          0           7           0
# 1463     48376          0           3           0
# 1464     48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# ...

# %%
df.to_csv('movies_directors.csv',index=False)

# %%
df=pd.read_csv('movies_directors.csv')

# %%
df
# Out:
#       movie_id     budget  popularity     revenue  \
# 0        43597  237000000         150  2787965087
# 1        43598  300000000         139   961000000
# 2        43599  245000000         107   880674609
# 3        43600  250000000         112  1084939099
# 4        43602  258000000         115   890871626
# ...        ...        ...         ...         ...
# 1460     48363          0           3      321952
# 1461     48370      27000          19     3151130
# 1462     48375          0           7           0
# 1463     48376          0           3           0
# 1464     48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# ...

# %% [markdown]
# # Dataset Overview
#
# The merged dataset contains the following columns:
#
# * movie_id: Unique ID for each movie.
# * budget: Budget of the movie.
# * popularity: Popularity score of the movie.
# * revenue: Revenue generated by the movie.
# * title: Title of the movie.
# * vote_average: Average user rating (vote) of the movie.
# * vote_count: Number of user votes.
# * director_id: Unique ID of the director.
# * year: Release year of the movie.
# * month: Release month of the movie.
# * day: Release day of the movie.
# * director_name: Name of the director.
# * gender: Gender of the director.
# * net_profit: Profit made by the movie (Revenue - Budget).
# * profit_margin: Profit margin of the movie.

# %%
df.size
# Out:
# 19045

# %%
df.shape
# Out:
# (1465, 13)

# %%
df.columns
# Out:
# Index(['movie_id', 'budget', 'popularity', 'revenue', 'title', 'vote_average',
#        'vote_count', 'director_id', 'year', 'month', 'day', 'director_name',
#        'gender'],
#       dtype='object')

# %% [markdown]
# ## Information of the Dataset
#
# * Columns = 13
# * Rows = 1465
# * Data types
#    - integer = 7
#    - float  1
#    - object = 5
# * Occur Null values
#    - Gender = 124

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movie_id       1465 non-null   int64
#  1   budget         1465 non-null   int64
#  2   popularity     1465 non-null   int64
#  3   revenue        1465 non-null   int64
#  4   title          1465 non-null   object
#  5   vote_average   1465 non-null   float64
#  6   vote_count     1465 non-null   int64
#  7   director_id    1465 non-null   int64
#  8   year           1465 non-null   int64
#  9   month          1465 non-null   object
#  10  day            1465 non-null   object
#  11  director_name  1465 non-null   object
#  12  gender         1341 non-null   object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 148.9+ KB

# %%
df.isnull().sum()
# Out:
# movie_id           0
# budget             0
# popularity         0
# revenue            0
# title              0
# vote_average       0
# vote_count         0
# director_id        0
# year               0
# month              0
# day                0
# director_name      0
# gender           124
# dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      1309
# Female      32
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#            movie_id        budget   popularity       revenue  vote_average  \
# count   1465.000000  1.465000e+03  1465.000000  1.465000e+03   1465.000000
# mean   45225.191126  4.802295e+07    30.855973  1.432539e+08      6.368191
# std     1189.096396  4.935541e+07    34.845214  2.064918e+08      0.818033
# min    43597.000000  0.000000e+00     0.000000  0.000000e+00      3.000000
# 25%    44236.000000  1.400000e+07    11.000000  1.738013e+07      5.900000
# 50%    45022.000000  3.300000e+07    23.000000  7.578164e+07      6.400000
# 75%    45990.000000  6.600000e+07    41.000000  1.792469e+08      6.900000
# max    48395.000000  3.800000e+08   724.000000  2.787965e+09      8.300000
#
#          vote_count  director_id         year
# count   1465.000000  1465.000000  1465.000000
# mean    1146.396587  5040.192491  2002.615017
# std     1578.077438   258.059631     8.680141
# min        1.000000  4762.000000  1976.000000
# 25%      216.000000  4845.000000  1998.000000
# ...

# %%
df.describe(include='all').T
# Out:
#                 count unique               top  freq              mean  \
# movie_id       1465.0    NaN               NaN   NaN      45225.191126
# budget         1465.0    NaN               NaN   NaN   48022946.879863
# popularity     1465.0    NaN               NaN   NaN         30.855973
# revenue        1465.0    NaN               NaN   NaN  143253923.075085
# title            1465   1465            Avatar     1               NaN
# vote_average   1465.0    NaN               NaN   NaN          6.368191
# vote_count     1465.0    NaN               NaN   NaN       1146.396587
# director_id    1465.0    NaN               NaN   NaN       5040.192491
# year           1465.0    NaN               NaN   NaN       2002.615017
# month            1465     12               Dec   193               NaN
# day              1465      7            Friday   654               NaN
# director_name    1465    199  Steven Spielberg    26               NaN
# ...

# %%
df.describe(include='object')
# Out:
#          title month     day     director_name gender
# count     1465  1465    1465              1465   1341
# unique    1465    12       7               199      2
# top     Avatar   Dec  Friday  Steven Spielberg   Male
# freq         1   193     654                26   1309

# %%
df.nunique()
# Out:
# movie_id         1465
# budget            201
# popularity        128
# revenue          1267
# title            1465
# vote_average       51
# vote_count       1019
# director_id       199
# year               41
# month              12
# day                 7
# director_name     199
# gender              2
# dtype: int64

# %%
for i in df.columns:
    print(i,":",df[i].unique())
# Out:
# movie_id : [43597 43598 43599 ... 48375 48376 48395]
# budget : [237000000 300000000 245000000 250000000 258000000 270000000 200000000
#  255000000 225000000 380000000 180000000 207000000 209000000 210000000
#  150000000 190000000 195000000 185000000 140000000 176000003 178000000
#  170000000 145000000 175000000 165000000 160000000  38000000 155000000
#   70000000 139000000 135000000 130000000 137000000 120000000 132000000
#  110000000 125000000 127000000  65000000 123000000 117000000 115000000
#  116000000 105000000  93000000 107000000 133000000 108000000 126000000
#   90000000 103000000 102000000 100000000  80000000  94000000  92000000
#          0  95000000  79000000  98000000  75000000  88000000  68000000
#   85000000  84000000  82500000   8000000  82000000  86000000  60000000
#   78000000  76000000  73000000  50000000  53000000  72500000  72000000
#   66000000  36000000  69000000  63000000  52000000  45000000  64000000
# ...

# %% [markdown]
# ## fill Null values

# %%
df['gender'].fillna(df['gender'].mode()[0],inplace=True)

# %%
df['gender'].mode()[0]
# Out:
# 'Male'

# %%
df.isnull().sum()
# Out:
# movie_id         0
# budget           0
# popularity       0
# revenue          0
# title            0
# vote_average     0
# vote_count       0
# director_id      0
# year             0
# month            0
# day              0
# director_name    0
# gender           0
# dtype: int64

# %% [markdown]
# ## Feature Engineering

# %%
df['net_profit']=df['revenue']-df['budget']

# %%
df
# Out:
#       movie_id     budget  popularity     revenue  \
# 0        43597  237000000         150  2787965087
# 1        43598  300000000         139   961000000
# 2        43599  245000000         107   880674609
# 3        43600  250000000         112  1084939099
# 4        43602  258000000         115   890871626
# ...        ...        ...         ...         ...
# 1460     48363          0           3      321952
# 1461     48370      27000          19     3151130
# 1462     48375          0           7           0
# 1463     48376          0           3           0
# 1464     48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# ...

# %%
df['profit_margin']=df['net_profit']/df['budget']*100

# %%
df
# Out:
#       movie_id     budget  popularity     revenue  \
# 0        43597  237000000         150  2787965087
# 1        43598  300000000         139   961000000
# 2        43599  245000000         107   880674609
# 3        43600  250000000         112  1084939099
# 4        43602  258000000         115   890871626
# ...        ...        ...         ...         ...
# 1460     48363          0           3      321952
# 1461     48370      27000          19     3151130
# 1462     48375          0           7           0
# 1463     48376          0           3           0
# 1464     48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Boxplot

# %%
plt.figure(figsize=(10,5))
df.boxplot()
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Correlation Heatmap of Movie Metrics

# %%
# Correlation heatmap
plt.figure(figsize=(10, 8))
corr_matrix = df[['budget', 'revenue', 'popularity', 'vote_average', 'vote_count', 'net_profit']].corr()
sns.heatmap(corr_matrix, annot=True,  fmt='.2f')
plt.title('Correlation Heatmap of Movie Metrics')
plt.show()

# %% [markdown]
# * Revenue and Budget: Strong positive correlation (0.71). Higher budget often leads to higher revenue.
# * Popularity and Revenue: Moderate positive correlation (0.59). More popular movies tend to earn more.
# * Vote Count and Popularity: Strong positive correlation (0.78). More votes usually mean higher popularity.
# * Net Profit and Revenue: Very strong positive correlation (0.98). Higher revenue almost always means higher net profit.
# * Vote Count and Revenue: Significant correlation (0.75). Movies with more votes tend to earn more.
# * Net Profit and Vote Count: Strong positive correlation (0.73). Higher net profit is often associated with more votes.
#
# This heatmap helps understand how different financial and rating aspects of movies are interrelated, which can be valuable for analysts in the film industry.

# %% [markdown]
# # Average Net Profit by Year

# %%
netprofit=df.groupby('year')['net_profit'].mean().reset_index()

# %%
netprofit
# Out:
#     year    net_profit
# 0   1976  3.499181e+07
# 1   1977  5.323834e+07
# 2   1978  9.011780e+07
# 3   1979  6.206198e+07
# 4   1980  3.000591e+07
# 5   1981  7.729623e+07
# 6   1982  1.084763e+08
# 7   1983  3.793489e+07
# 8   1984  5.390088e+07
# 9   1985  5.475322e+07
# 10  1986  6.732639e+07
# 11  1987  6.392700e+07
# 12  1988  7.045489e+07
# 13  1989  8.427938e+07
# 14  1990  1.159951e+08
# 15  1991  1.540039e+08
# 16  1992  8.147870e+07
# 17  1993  1.348915e+08
# 18  1994  1.081913e+08
# 19  1995  7.390588e+07
# 20  1996  7.273568e+07
# 21  1997  9.778449e+07
# 22  1998  5.420046e+07
# 23  1999  4.675535e+07
# 24  2000  7.982657e+07
# 25  2001  8.207359e+07
# 26  2002  9.911952e+07
# 27  2003  1.047129e+08
# 28  2004  1.022819e+08
# 29  2005  7.732120e+07
# 30  2006  8.509676e+07
# 31  2007  1.021975e+08
# 32  2008  9.957618e+07
# 33  2009  1.212515e+08
# 34  2010  1.017195e+08
# 35  2011  9.626864e+07
# 36  2012  1.454995e+08
# 37  2013  1.007159e+08
# 38  2014  1.381838e+08
# ...

# %%
plt.figure(figsize=(15,8))
plt.plot(netprofit['year'],netprofit['net_profit'],marker='o',color='r')
plt.xlabel('Year',color='b')
plt.ylabel('Average Net Profit',color='b')
plt.title('Average Net Profit by Year',fontweight='bold')
plt.show()

# %% [markdown]
# #### Fluctuating Trend:
#   The average net profit shows significant fluctuations over the years, with both upward and downward trends.
# #### No Consistent Increase:
#
#   The net profit does not show a consistent increasing trend over the years..

# %% [markdown]
# # Comparative Analysis of Revenue and Budget Over Years

# %%
revenue_budget=df.groupby('year')[['revenue','budget']].mean().reset_index()

# %%
revenue_budget
# Out:
#     year       revenue        budget
# 0   1976  3.762514e+07  2.633333e+06
# 1   1977  5.817334e+07  4.935000e+06
# 2   1978  1.065178e+08  1.640000e+07
# 3   1979  8.153698e+07  1.947500e+07
# 4   1980  4.056841e+07  1.056250e+07
# 5   1981  8.671441e+07  9.418182e+06
# 6   1982  1.205263e+08  1.205000e+07
# 7   1983  5.471845e+07  1.678356e+07
# 8   1984  7.542088e+07  2.152000e+07
# 9   1985  6.872933e+07  1.397611e+07
# 10  1986  7.949002e+07  1.216364e+07
# 11  1987  7.893534e+07  1.500833e+07
# 12  1988  7.970873e+07  9.253846e+06
# 13  1989  1.053827e+08  2.110333e+07
# 14  1990  1.487728e+08  3.277778e+07
# 15  1991  1.903372e+08  3.633333e+07
# 16  1992  1.091662e+08  2.768752e+07
# 17  1993  1.639193e+08  2.902778e+07
# 18  1994  1.379664e+08  2.977506e+07
# 19  1995  1.125044e+08  3.859848e+07
# 20  1996  1.094552e+08  3.671957e+07
# 21  1997  1.502138e+08  5.242935e+07
# 22  1998  9.374357e+07  3.954311e+07
# 23  1999  9.266178e+07  4.590644e+07
# ...

# %%
plt.figure(figsize=(15,8))
plt.plot(revenue_budget['year'],revenue_budget['revenue'],marker='*',color='g')
plt.plot(revenue_budget['year'],revenue_budget['budget'],marker='o',color='yellow')
plt.legend(['Revenue','Budget'])
plt.xlabel('Year',color='b')
plt.ylabel('Average Revenue / Budget',color='b')
plt.title('Average Revenue and Budget by Year',fontsize=15,fontweight='bold')
plt.show()

# %% [markdown]
# * As depicted in the graph, while both revenue and budget have increased over time, revenue has shown a significant upward trend with greater variability compared to the relatively steady increase of the budget.

# %%
plt.figure(figsize=(10,5))
plt.xlabel('Revenue',color='b')
plt.ylabel('Budget',color='b')
plt.title('Relationship between Revenue and Budget',fontsize=15,fontweight='bold')
plt.scatter(revenue_budget['revenue'],revenue_budget['budget'])
plt.show()

# %% [markdown]
# * The scatter plot indicates a positive correlation between budget and revenue.

# %% [markdown]
# # Revenue Analysis by Day and Month

# %%
plt.figure(figsize=(15,6))
plt.title('Revenue by Release Day',fontsize=15,fontweight='bold')
plt.xlabel('Release Day',color='b')
plt.ylabel('Revenue',color='b')
plt.bar(df['day'],df['revenue'],color='pink')
plt.show()

# %% [markdown]
# * Thursday generates significantly higher revenue compared to other days, with Tuesday showing the second-highest revenue figures.

# %%
plt.figure(figsize=(15,6))
plt.title('Revenue by Release Month',fontsize=15,fontweight='bold')
plt.xlabel('Release Month',color='b')
plt.ylabel('Revenue',color='b')
plt.bar(df['month'],df['revenue'],color='skyblue')
plt.show()

# %% [markdown]
# * December generates the highest revenue compared to other months.
# * May and June also show high revenues, while November and April have comparatively moderate revenue

# %%
plt.figure(figsize=(15,8))
sns.barplot(x='month',y='revenue',data=df,hue='day')
plt.title('Monthly Revenue Breakdown by Day',fontsize=15,fontweight='bold')
plt.show()

# %% [markdown]
# #### Consistent High Revenue Days:
# Fridays and Saturdays consistently show higher revenue compared to other days across most months.
# #### Monthly Trends:
# Revenue peaks in November, May and April, likely due to holiday shopping, and dips in the summer months.
# #### Weekday vs. Weekend:
# Weekends (Saturday and Sunday) generally outperform weekdays, indicating higher consumer activity during weekends.
# #### Variability:
# Some months, like March and September, show more variability in daily revenue, suggesting potential promotional events or seasonal factors.

# %% [markdown]
# # Popularity Over Time

# %%
plt.figure(figsize=(15,8))
plt.title('Trend of Movie Popularity Over the Years',fontsize=15,fontweight='bold')
sns.lineplot(x='year',y='popularity',data=df)
plt.show()

# %% [markdown]
# * Movie popularity fluctuates each year, but there is a significant increase starting around 2005, peaking sharply by 2015.

# %% [markdown]
# # Vote Average Distribution

# %%
plt.figure(figsize=(10,5))
plt.title('Distribution of Movie Ratings',fontsize=15,fontweight='bold')
plt.xlabel('Average Vote',color='b')
plt.ylabel('Count',color='b')
plt.hist(df['vote_average'],bins=10,color='g',edgecolor='grey')
plt.show()

# %% [markdown]
# * The distribution indicates a higher frequency of average votes in the range of 6 to 7 compared to other ratings.

# %% [markdown]
# # Director’s Gender Distribution

# %%
df['gender'].value_counts().plot(kind='pie',explode=(0,0.1),autopct='%1.2f%%')
plt.title('Gender Distribution of Directors',fontsize=15,fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# * The vast majority of directors are male, comprising 97.82% of the total, while only 2.18% are female.

# %% [markdown]
# # Vote Count vs. Vote Average

# %%
plt.figure(figsize=(10,5))
plt.title('Vote Count vs. Vote Average',fontsize=15,fontweight='bold')
plt.scatter(df['vote_count'],df['vote_average'])
plt.show()

# %% [markdown]
# #### Vote Count Distribution:
# There are fewer instances with high vote counts. As the vote count increases, the number of data points decreases.
# #### Vote Average Range:
# The vote averages mostly range from 6 to 8, even for items with higher vote counts.

# %% [markdown]
# # Top Directors by Number of Movies and Average Net Profit

# %%
director_counts = df.groupby('director_name').agg(
    movie_count=('director_name', 'count'),
    avg_net_profit=('net_profit', 'mean')
).sort_values(by=['movie_count','avg_net_profit'],ascending=False).reset_index().head(15)

# %%
director_counts
# Out:
#         director_name  movie_count  avg_net_profit
# 0    Steven Spielberg           26    2.698554e+08
# 1      Clint Eastwood           19    9.181889e+07
# 2     Martin Scorsese           19    5.534400e+07
# 3         Woody Allen           18    2.271702e+07
# 4        Ridley Scott           16    1.187224e+08
# 5    Robert Rodriguez           16    3.797997e+07
# 6           Spike Lee           16    9.107423e+06
# 7   Steven Soderbergh           15    9.997763e+07
# 8        Renny Harlin           15    1.868004e+07
# 9          Tim Burton           14    1.671727e+08
# 10       Oliver Stone           14    4.996062e+07
# 11    Robert Zemeckis           13    2.000478e+08
# 12         Ron Howard           13    1.464147e+08
# 13    Joel Schumacher           13    6.557974e+07
# 14     Barry Levinson           13    5.417325e+07

# %%
plt.figure(figsize=(15, 8))
sns.barplot(x='movie_count', y='director_name', data=director_counts, palette='viridis')

plt.xlabel('Number of Movies',color='b')
plt.ylabel('Director Name',color='b')
plt.title('Top 15 Directors by Number of Movies',fontsize=15,fontweight='bold')
plt.show()

# %% [markdown]
# * Steven Spielberg has directed a significant number of movies, he is the highest among the top 15 directors by number of movies.

# %%
top_directors = df.groupby('director_name')['net_profit'].mean().sort_values(ascending=False).head(10).reset_index()
top_directors
# Out:
#        director_name    net_profit
# 0      James Cameron  7.338099e+08
# 1      Peter Jackson  5.784048e+08
# 2   Francis Lawrence  4.698914e+08
# 3  Christopher Nolan  4.028104e+08
# 4     Andrew Adamson  3.983719e+08
# 5        Michael Bay  3.685437e+08
# 6        Jon Favreau  3.003090e+08
# 7          James Wan  2.988021e+08
# 8     Gore Verbinski  2.957162e+08
# 9         Sam Mendes  2.927927e+08

# %%
plt.figure(figsize=(15, 8))
sns.barplot(x='director_name', y='net_profit', data=top_directors, palette='viridis')
plt.xticks(rotation=90)
plt.xlabel('Director Name',color='b')
plt.ylabel('Average Net Profit',color='b')
plt.title('Top 10 Directors by Net Profit ',fontsize=15,fontweight='bold')
plt.show()

# %% [markdown]
# * James Cameron leads with the highest average net profit, significantly higher than the rest.
# * Peter Jackson holds the second position, with roughly half the average net profit of James Cameron.
# * Francis Lawrence is third, closely followed by Christopher Nolan in fourth place.
# * Andrew Adamson and Michael Bay are nearly tied for fifth and sixth places, respectively.
# * Jon Favreau, Joss Wan, Gore Verbinski, and Sam Mendes make up the lower four positions on the chart with relatively similar average net profits.

# %%
df.columns
# Out:
# Index(['movie_id', 'budget', 'popularity', 'revenue', 'title', 'vote_average',
#        'vote_count', 'director_id', 'year', 'month', 'day', 'director_name',
#        'gender', 'net_profit', 'profit_margin'],
#       dtype='object')

# %% [markdown]
# # Analysis of Movie Success Level

# %%
df['revenue'].max()
# Out:
# 2787965087

# %%
df['revenue'].min()
# Out:
# 0

# %%
def categorize_movie(revenue):
    if revenue<=0:
        return 'Flop'
    elif revenue<=10000000:
        return 'Average'
    elif revenue<=100000000:
        return 'Hit'
    elif revenue<=1000000000:
        return 'Super Hit'
    else:
        return 'Blockbuster'
    
df['success_level']=df['revenue'].apply(categorize_movie)

# %%
df
# Out:
#       movie_id     budget  popularity     revenue  \
# 0        43597  237000000         150  2787965087
# 1        43598  300000000         139   961000000
# 2        43599  245000000         107   880674609
# 3        43600  250000000         112  1084939099
# 4        43602  258000000         115   890871626
# ...        ...        ...         ...         ...
# 1460     48363          0           3      321952
# 1461     48370      27000          19     3151130
# 1462     48375          0           7           0
# 1463     48376          0           3           0
# 1464     48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# ...

# %%
df['success_level'].value_counts().plot(kind='pie',autopct='%1.2f%%',explode=(0,0,0,0,0.1))
plt.title('Analysis of Movie Success Level',fontsize=15,fontweight='bold')
plt.show()

# %% [markdown]
# * In this analysis, ‘Super Hit’ and ‘Hit’ movies have high percentages, while ‘Blockbuster’ movies have a very low count.

# %% [markdown]
# # Analysis of Most Popular Movies

# %%
df['title'].value_counts()
# Out:
# title
# Avatar                      1
# My Fellow Americans         1
# I Heart Huckabees           1
# Homefront                   1
# Hail, Caesar!               1
#                            ..
# The Godfather: Part III     1
# Blade II                    1
# A Very Long Engagement      1
# The Phantom of the Opera    1
# El Mariachi                 1
# Name: count, Length: 1465, dtype: int64

# %%
df['popularity'].value_counts()
# Out:
# popularity
# 14     45
# 16     42
# 5      41
# 7      39
# 6      38
#        ..
# 206     1
# 103     1
# 132     1
# 88      1
# 121     1
# Name: count, Length: 128, dtype: int64

# %%
df['popularity'].unique()
# Out:
# array([150, 139, 107, 112, 115, 155,  57, 145,  49,  99,  53, 135,  52,
#        120,  37,  94,  42,  61, 100,  64,  93,  35,  78,   3,  21, 116,
#         46,  51,  71, 102,  81, 118,  43,  62,  56,  28,  75,  65,  22,
#         45,  39,  85,  67, 187,  32,  40,  60,  90,  27,  79,  44,  77,
#         47,  48, 724, 167, 108,   6, 127,  34,  25, 101,  70,  73, 434,
#         86,  50,  33,  38,  66,  54,  58,  91,  82,  17,  24,  59,  29,
#         76,  89, 109, 271, 206,   2,   7,  41,  68,  15,  18, 143,  16,
#         23, 103,  36, 138,  95,  30,   1, 132,  88,  20,  12,  19, 123,
#        106, 104,  63, 140,  55,   8,  31,  13,  14,  26,  11,   9,  10,
#          4,  72, 146,  87,   5,  83,  74,  80,  69,   0, 121], dtype=int64)

# %%
df['popularity'].max()
# Out:
# 724

# %%
df['popularity'].min()
# Out:
# 0

# %%
popular=df.groupby('title')['popularity'].sum().reset_index().sort_values(by='popularity',ascending=False).reset_index(drop=True).head(20)

# %%
popular
# Out:
#                                                 title  popularity
# 0                                        Interstellar         724
# 1                                  Mad Max: Fury Road         434
# 2   Pirates of the Caribbean: The Curse of the Bla...         271
# 3               The Hunger Games: Mockingjay - Part 1         206
# 4                                     The Dark Knight         187
# 5                                         The Martian         167
# 6                                           Inception         167
# 7                  Batman v Superman: Dawn of Justice         155
# 8                                              Avatar         150
# 9                                          Fight Club         146
# 10         Pirates of the Caribbean: Dead Man's Chest         145
# 11                       Teenage Mutant Ninja Turtles         143
# 12                                          Gone Girl         143
# ...

# %%
plt.figure(figsize=(15,8))
plt.bar(popular['title'],popular['popularity'],color='darkgreen')
plt.title('Top 20 Popular Movies',fontsize=15,fontweight='bold')
plt.xlabel('Movie Name',color='b')
plt.ylabel('Popularity Count',color='b')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# * Among the top 20 popular movies, ‘Interstellar’ is the most popular, followed by ‘Mad Max: Fury Road’.

# %% [markdown]
# # Overall Insights on Factors Influencing Movie Success

# %% [markdown]
# ### Fluctuating Profit Trends:
# * The net profit of movies has shown both upward and downward trends over the years without a consistent increase.
# * This highlights the unpredictability of movie success and the influence of external factors like competition, economic conditions, and audience preferences.
#
# ### Revenue and Budget Correlation:
# * While both the revenue and budget of movies have increased over time, revenue has exhibited a more significant upward trend with greater variability.
# * The scatter plot indicates a positive correlation between budget and revenue, suggesting that higher-budget movies generally generate more revenue.
#
# ### Impact of Days and Months on Revenue:
# * Thursday generates the highest revenue, followed by Tuesday, showing that these are prime days for movie releases.
# * December is the most profitable month, with May and June also performing well.
# * Fridays and Saturdays show consistently high revenues across months, which aligns with increased weekend viewership.
#
# ### Monthly and Weekly Revenue Trends:
# * Revenue tends to peak in May, November, and April, likely due to the holiday season and major film releases during these months.
# * Weekends consistently outperform weekdays, emphasizing the importance of releasing films on Fridays or Saturdays to maximize revenue.
# * Months like March and September show high variability, potentially driven by seasonal events and promotional activities.
#
# ### Popularity and Vote Distribution:
# * Movie popularity has fluctuated over time but has significantly increased since 2005, peaking in 2015.
# * The vote distribution reveals that most movies receive average ratings between 6 and 7.
# * Higher vote counts are rarer, with most movies receiving moderate engagement.
#
# ### Gender Disparity in Direction:
# * The analysis reveals a significant gender imbalance in the directing profession, with 97.82% of directors being male and only 2.18% being female.
# * This suggests the need for increased diversity and inclusion in the film industry.
#
# ### Top Directors and Profitability:
# * James Cameron leads with the highest average net profit among directors, followed by Peter Jackson and Francis Lawrence.
# * Steven Spielberg has directed the most movies, but Cameron’s films yield higher profits.
# * Directors like Christopher Nolan, Michael Bay, and Sam Mendes also contribute to profitable ventures.
#
# ### Movie Success Categories:
# * While ‘Super Hit’ and ‘Hit’ movies dominate, ‘Blockbusters’ are relatively rare, indicating that even high-budget films may not always achieve the highest level of success.
#
# ### Top 20 Popular Movies:
# * Among the most popular movies, Interstellar and Mad Max: Fury Road are at the top, reflecting their strong fan base and critical acclaim.

# %% [markdown]
# # Recommendations

# %% [markdown]
# ### Optimizing Release Dates:
# * Given the higher revenues on Thursdays, Fridays, and weekends, movie studios should prioritize releasing films on these days.
# * December, May, and June should be targeted for major releases due to their high revenue potential, while avoiding quieter months unless driven by promotional efforts.
#
# ### Budget Allocation and Risk Management:
# * Since higher budgets correlate with higher revenues, studios should invest in big-budget movies but remain mindful of fluctuating profits.
# * Risk management strategies should involve diversifying movie genres and budgets to avoid over-reliance on a few high-cost projects.
#
# ### Leveraging Audience Preferences:
# * Movies with an average vote between 6 and 7 are more common, so marketing strategies should focus on engaging with this audience through tailored promotions.
# * High engagement with platforms where movies are rated should be encouraged to increase visibility.
#
# ### Promoting Diversity in Directing:
# * The stark gender disparity in directors calls for increased opportunities for women in filmmaking.
# * Studios should consider investing in films directed by women and supporting diversity initiatives to broaden the creative pool and perspective.
#
# ### Maximizing Seasonal and Promotional Opportunities:
# * March and September's high variability in revenue may indicate promotional opportunities.
# * Studios should consider launching promotional campaigns or re-releasing successful films during these months to boost revenue.
#
# ### Targeting Popular Directors for Profitability:
# * Collaborating with highly profitable directors like James Cameron, Peter Jackson, or Christopher Nolan should be prioritized for major projects, as they tend to deliver higher returns.

# %% [markdown]
# # Conclusion

# %% [markdown]
# In conclusion, this analysis highlights several key factors influencing movie success, including fluctuating net profits, the strong correlation between budget and revenue, and the significant impact of release days and months on profitability. While male directors dominate the industry, those like James Cameron and Steven Spielberg have consistently driven high profits. Additionally, consumer behavior shows a preference for weekend viewings and holiday seasons, emphasizing the importance of strategic release timing. By addressing these insights and promoting diversity, studios can better position themselves for sustained success in an unpredictable market.
